# %% [markdown]
# <a href="https://colab.research.google.com/github/Maithiliss/ImageClassification/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-332d1e2e-b8d8-4d3d-8fbf-656d4086a26b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-332d1e2e-b8d8-4d3d-8fbf-656d4086a26b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "/content/archive (3).zip"
extract_path = "/content/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
import os

print(os.listdir("/content/dataset"))
# Out:
# ['archive']

# %%
import os

print(os.listdir("/content/dataset/archive"))
# Out:
# ['train', 'test']

# %%
train_path = "/content/dataset/archive/train"
test_path = "/content/dataset/archive/test"

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cats', 'dogs']

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import layers, models

# %%
import tensorflow as tf

train_path = "/content/dataset/archive/train"
test_path = "/content/dataset/archive/test"

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(224, 224),
    batch_size=32
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_path,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y))

train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models

base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False

# %%
model = models.Sequential([
    base_model,
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(2, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=5
)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 161s 252ms/step - accuracy: 0.9646 - loss: 0.3761 - val_accuracy: 0.9792 - val_loss: 0.1022
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 203s 256ms/step - accuracy: 0.9794 - loss: 0.0619 - val_accuracy: 0.9810 - val_loss: 0.0655
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 159s 254ms/step - accuracy: 0.9821 - loss: 0.0591 - val_accuracy: 0.9836 - val_loss: 0.0569
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 203s 256ms/step - accuracy: 0.9829 - loss: 0.0487 - val_accuracy: 0.9846 - val_loss: 0.0613
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 159s 255ms/step - accuracy: 0.9874 - loss: 0.0403 - val_accuracy: 0.9852 - val_loss: 0.0543

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02da1851-d66f-4695-91b2-c1fe79937342" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02da1851-d66f-4695-91b2-c1fe79937342">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'Screenshot 2026-07-01 132151 (3).png', 'archive (3) (1).zip', 'Screenshot 2026-07-01 132151 (2).png', 'dataset', 'pic (1).png', 'Screenshot 2026-07-01 132151 (1).png', 'pic.png', 'archive (3).zip', 'Screenshot 2026-07-01 143137.png', '.ipynb_checkpoints', 'Screenshot 2026-07-01 132151.png', 'sample_data']

# %%
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

img_name = list(uploaded.keys())[0]   # automatically uploaded file
img_path = "/content/" + img_name

img = load_img(img_path, target_size=(224, 224))
img = img_to_array(img)
img = np.expand_dims(img, axis=0)
img = preprocess_input(img)

pred = model.predict(img)

class_names = ['cats', 'dogs']
print(class_names[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# cats
